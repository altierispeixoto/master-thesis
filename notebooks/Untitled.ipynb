# %%
# %reload_ext cypher

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match (l:Line {line_code:'666'})-[:HAS_TRIP]-(t:Trip)-[:HAS_SCHEDULE_AT]->(sc:Schedule)
# return distinct l.name as line_name, t.line_way as line_way, sc.vehicle as vehicle,sc.start_time as start_time,sc.end_time as end_time,sc.time_table as time_table
# order by vehicle,time_table,start_time,end_time
# Out:
# 62 rows affected.
# [['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '06:00', '06:35', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '06:35', '07:08', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '07:08', '07:43', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '07:43', '08:16', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '08:16', '08:50', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '08:50', '09:24', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '09:24', '09:58', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '09:58', '10:32', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '10:32', '11:06', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '11:06', '11:40', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '11:40', '12:14', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '12:14', '12:48', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '12:48', '13:22', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '13:22', '13:56', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '13:56', '14:30', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '14:30', '15:04', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '15:04', '15:38', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '15:38', '16:12', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '16:12', '16:46', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '16:46', '17:20', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '17:20', '17:53', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '17:53', '18:28', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '18:28', '19:01', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '19:01', '19:36', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '19:36', '20:10', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '20:10', '20:44', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '20:44', '21:18', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '21:18', '21:52', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '21:52', '22:26', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN606', '22:26', '23:00', '1'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN606', '23:00', '23:32', '1'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '00:05', '00:36', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '06:34', '07:09', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '07:09', '07:42', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '07:42', '08:17', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '08:17', '08:50', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '08:50', '09:24', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '09:24', '09:58', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '09:58', '10:32', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '10:32', '11:06', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '11:06', '11:40', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '11:40', '12:14', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '12:14', '12:48', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '12:48', '13:22', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '13:22', '13:56', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '13:56', '14:30', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '14:30', '15:04', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '15:04', '15:38', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '15:38', '16:12', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '16:12', '16:46', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '16:46', '17:20', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '17:20', '17:54', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '17:54', '18:27', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '18:27', '19:02', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '19:02', '19:35', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '19:35', '20:10', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '20:10', '20:44', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '20:44', '21:18', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '21:18', '21:52', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '21:52', '22:26', '2'],
#  ['NOVO MUNDO', 'Praca Rui Barbosa', 'GN608', '22:26', '23:00', '2'],
#  ['NOVO MUNDO', 'Novo Mundo', 'GN608', '23:00', '23:34', '2']]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match(l:Line {line_code:'666'})-[:HAS_TRIP]-(t:Trip)-[:HAS_SCHEDULE_AT]->(sc:Schedule)
# with distinct l.name as line_name, t.line_way as line_way, sc.vehicle as vehicle
# match (t:Trip {line_way: line_way})-[:STARTS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(ss:Stop {vehicle: vehicle})
# with ss, line_name , line_way , vehicle
# MATCH(t:Trip {line_way: line_way})-[:ENDS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(se:Stop {vehicle: vehicle})
# with line_name ,vehicle, line_way,ss.event_time as start_event, se.event_time as end_event where ss.event_time < se.event_time
# with line_name ,vehicle, line_way, start_event, min(end_event) as end_event
# with line_name ,vehicle, line_way, min(start_event) as start_event , end_event
# match (t:Trip {line_way: line_way})-[:STARTS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(ss:Stop {vehicle: vehicle})
# where ss.event_time = start_event
# with line_name ,vehicle, line_way, ss,start_event, end_event
# MATCH(t:Trip {line_way: line_way})-[:ENDS_ON_POINT]->(bs:BusStop  )<-[:EVENT_STOP]-(se:Stop {vehicle: vehicle})
# where se.event_time = end_event
# WITH line_name ,vehicle, line_way, ss, se ,start_event , end_event
# match p = (ss)-[m:MOVED_TO*]->(se)
# with line_name ,vehicle, line_way, start_event , end_event, extract(s in relationships(p) | toFloat(s.delta_time))     as delta_time
#     ,extract(s in relationships(p) | toFloat(s.delta_distance)) as delta_distance
#     ,extract(s in relationships(p) | toFloat(s.delta_velocity)) as delta_velocity
#     ,length(extract(s in nodes(p) where 'Stop' IN LABELS(s) )) as stop
# return line_name ,vehicle, line_way, min(start_event) as start_event, end_event, apoc.coll.sum(delta_time)/60        as time_in_minutes
#       ,apoc.coll.sum(delta_distance)/1000  as distance_in_kilometers
#       ,apoc.coll.avg(delta_velocity)       as velocity_in_kmh
#       ,stop
# order by vehicle,start_event, end_event
# Out:
# 43 rows affected.
# [['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '06:25:33',
#   '07:07:29',
#   41.93333333333333,
#   10.381746799827244,
#   18.192051282051278,
#   40],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '07:07:29',
#   '07:49:24',
#   41.916666666666664,
#   12.352272064877159,
#   15.284264705882348,
#   69],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '07:49:24',
#   '08:18:35',
#   29.183333333333334,
#   10.460990179629057,
#   16.876923076923074,
#   40],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '08:18:35',
#   '08:55:30',
#   36.916666666666664,
#   12.02039691100763,
#   16.199827586206897,
#   59],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '08:55:30',
#   '10:28:00',
#   92.5,
#   32.83156882182685,
#   16.38488372093023,
#   130],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '10:28:00',
#   '11:05:13',
#   37.21666666666667,
#   11.387766887538232,
#   19.095945945945946,
#   38],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '11:05:13',
#   '11:37:23',
#   32.166666666666664,
#   10.173029943904087,
#   18.335757575757572,
#   34],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '11:37:23',
#   '12:09:19',
#   31.933333333333334,
#   11.234269784762459,
#   18.911944444444444,
#   37],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '12:09:19',
#   '12:38:22',
#   29.05,
#   10.380629211409094,
#   17.79266666666667,
#   46],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '12:38:22',
#   '13:21:31',
#   43.15,
#   11.714390369426878,
#   17.34163265306122,
#   50],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '13:21:31',
#   '13:44:13',
#   22.7,
#   10.055162168749032,
#   21.048846153846153,
#   27],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '13:44:13',
#   '14:29:43',
#   45.5,
#   11.823569960296979,
#   17.509090909090904,
#   45],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '14:29:43',
#   '15:00:01',
#   30.3,
#   10.428746036842972,
#   16.536500000000007,
#   41],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '15:00:01',
#   '15:34:08',
#   34.11666666666667,
#   11.5657714885855,
#   16.73775,
#   41],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '15:34:08',
#   '16:06:50',
#   32.7,
#   10.45017232830618,
#   16.950714285714287,
#   29],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '16:06:50',
#   '17:03:27',
#   56.61666666666667,
#   13.948621031694914,
#   13.111159420289853,
#   70],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '17:03:27',
#   '18:15:24',
#   71.95,
#   11.526357995749803,
#   11.31240506329114,
#   80],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '18:15:24',
#   '19:09:20',
#   53.93333333333333,
#   12.699655629975643,
#   14.276984126984123,
#   64],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '19:09:20',
#   '20:04:37',
#   55.28333333333333,
#   11.295770116735929,
#   12.139516129032256,
#   63],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '20:04:37',
#   '20:38:35',
#   33.96666666666667,
#   11.652277587707852,
#   16.08634146341464,
#   42],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '20:38:35',
#   '21:13:32',
#   34.95,
#   10.440112044719639,
#   15.26357142857143,
#   43],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '21:13:32',
#   '21:48:30',
#   34.96666666666667,
#   11.314801830622095,
#   18.872857142857146,
#   29],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '21:48:30',
#   '22:17:23',
#   28.883333333333333,
#   10.27848981561118,
#   15.843,
#   41],
#  ['NOVO MUNDO',
#   'GN606',
#   'Praca Rui Barbosa',
#   '22:17:23',
#   '22:48:37',
#   31.233333333333334,
#   11.452418792232416,
#   17.937666666666665,
#   31],
#  ['NOVO MUNDO',
#   'GN606',
#   'Novo Mundo',
#   '22:48:37',
#   '23:14:54',
#   26.283333333333335,
#   10.20608628233774,
#   16.989285714285714,
#   29],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '06:37:04',
#   '07:06:26',
#   29.366666666666667,
#   11.421417512339154,
#   18.64054054054054,
#   38],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '07:06:26',
#   '07:39:25',
#   32.983333333333334,
#   10.783086656189154,
#   18.25065217391304,
#   47],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '07:39:25',
#   '08:19:59',
#   40.56666666666667,
#   12.460791824672487,
#   14.521481481481478,
#   82],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '08:19:59',
#   '11:04:22',
#   164.38333333333333,
#   54.87694768348361,
#   18.540209424083777,
#   192],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '11:04:22',
#   '11:35:13',
#   30.85,
#   11.918605934067065,
#   19.354285714285723,
#   50],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '11:35:13',
#   '12:11:48',
#   36.583333333333336,
#   10.728105804468766,
#   15.26980769230769,
#   53],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '12:11:48',
#   '12:42:33',
#   30.75,
#   11.908389041935036,
#   18.964313725490193,
#   52],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '12:42:33',
#   '13:22:24',
#   39.85,
#   11.101338683351468,
#   17.070204081632653,
#   50],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '13:22:24',
#   '13:53:15',
#   30.85,
#   11.968889968774512,
#   18.56035714285714,
#   57],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '13:53:15',
#   '14:23:31',
#   30.266666666666666,
#   10.468202521447697,
#   19.285000000000004,
#   41],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '14:23:31',
#   '14:59:52',
#   36.35,
#   11.768800159375974,
#   17.011190476190478,
#   43],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '14:59:52',
#   '18:59:54',
#   240.03333333333333,
#   59.16437995496512,
#   12.93483766233766,
#   309],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '18:59:54',
#   '19:44:07',
#   44.21666666666667,
#   11.89138979023856,
#   12.906862745098037,
#   52],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '19:44:07',
#   '20:20:27',
#   36.333333333333336,
#   10.789624571032082,
#   15.098478260869571,
#   47],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '20:20:27',
#   '20:45:27',
#   25.0,
#   11.250477417718288,
#   20.228148148148147,
#   28],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '20:45:27',
#   '21:18:01',
#   32.56666666666667,
#   10.033507716342367,
#   11.135384615384615,
#   40],
#  ['NOVO MUNDO',
#   'GN608',
#   'Praca Rui Barbosa',
#   '21:18:01',
#   '21:47:24',
#   29.383333333333333,
#   11.47484327990432,
#   19.41,
#   34],
#  ['NOVO MUNDO',
#   'GN608',
#   'Novo Mundo',
#   '21:47:24',
#   '23:26:04',
#   98.66666666666667,
#   32.33104477083121,
#   17.01694736842105,
#   96]]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# CALL algo.pageRank.stream('BusStop', 'NEXT_STOP', {iterations:20, dampingFactor:0.85})
# YIELD nodeId, score
# RETURN algo.asNode(nodeId).name AS bus_stop,score
# ORDER BY score DESC LIMIT 10
# Out:
# 10 rows affected.
# [['Rua Heitor S de Franca, 93 - Centro Civico', 5.521397324092686],
#  ['Av. Winston Churchill, 2472 - Cap?o Raso', 5.5211358696222295],
#  ['Rua Cruz Machado, 301 - Centro', 4.503339422680438],
#  ['Av. Winston Churchill, 2677 - Cap?o Raso', 4.262217385694385],
#  ['Rua Emanoel Voluz, 284 - Pinheirinho', 4.095777991600334],
#  ['Rua Des. Westphalen, 793 - Reboucas', 3.7757412413135167],
#  ['Rua Alferes Poli, 400 - Reboucas', 3.744606554321945],
#  ['Rua Vinte e Quatro de Maio, 280-350 - Centro', 3.7393020959571004],
#  ['Rua Nicola Pellanda, 1719 - Pinheirinho', 3.727981100603938],
#  ['Rua Rezala Sim?o, 997 - Santa Quiteria', 3.614147630613297]]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# CALL algo.pageRank.stream('BusStop', 'NEXT_STOP', {iterations:20, dampingFactor:0.85})
# YIELD nodeId, score
# with algo.asNode(nodeId) AS node,score ORDER BY score DESC LIMIT 15
# MATCH()-[r:NEXT_STOP]->(node)
# return node.name as bus_stop,count(distinct r.line_code) as linhas order by linhas desc
# Out:
# 15 rows affected.
# [['Rua Alferes Poli, 400 - Reboucas', 27],
#  ['Av. Winston Churchill, 2472 - Cap?o Raso', 25],
#  ['Av. Winston Churchill, 2677 - Cap?o Raso', 25],
#  ['Rua Heitor S de Franca, 93 - Centro Civico', 18],
#  ['Rua Emanoel Voluz, 284 - Pinheirinho', 18],
#  ['Rua Vinte e Quatro de Maio, 280-350 - Centro', 18],
#  ['Rua Cruz Machado, 301 - Centro', 16],
#  ['Rua Des. Westphalen, 793 - Reboucas', 16],
#  ['Rodovia BR476, 21283 - Cidade Industrial', 15],
#  ['Rua Conselheiro Laurindo, 1264- Centro', 10],
#  ['Rua Nicola Pellanda, 1719 - Pinheirinho', 8],
#  ['Rua Rezala Sim?o, 997 - Santa Quiteria', 7],
#  ['Rua Nicola Pellanda, 2091 - Pinheirinho', 7],
#  ['R. Gen. Potiguara, 2802 - Fazendinha', 7],
#  ['Rua Via Veneto, 1104 - Santa Felicidade', 6]]

# %% [markdown]
# **Betweenness centrality is a way of detecting the amount of influence a node has over the flow of information in a graph. It is often used to find nodes that serve as a bridge from one part of a graph to another.**

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# CALL algo.betweenness.stream('BusStop', 'NEXT_STOP', {direction:'out'})
# YIELD nodeId, centrality
# RETURN algo.asNode(nodeId).name AS bus_stop,centrality
# ORDER BY centrality DESC LIMIT 10
# Out:
# 10 rows affected.
# [['Rua Lea Moreira de Souza Moura, 11 - Cidade Industrial',
#   13450164.964056594],
#  ['Alameda Pres. Taunay, 1826 - Merces', 11286237.861624131],
#  ['Av. Manoel Ribas, 1363 - Merces', 9662392.441156248],
#  ['Av. Manoel Ribas, 1140 - Merces', 9662363.441156248],
#  ['Av. Manoel Ribas, 3401 - Cascatinha', 9462895.032516122],
#  ['Av. Manoel Ribas, 2262 - Merces', 9462866.032516122],
#  ['Av. Manoel Ribas, 2261 - Merces', 9462837.032516122],
#  ['Av. Manoel Ribas, 1821 - Merces', 9462808.032516122],
#  ['Av. Manoel Ribas, 1495 - Merces', 9462779.032516122],
#  ['Rua Iapo, 1158 - Prado Velho', 9296844.44318574]]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# CALL algo.closeness.stream('BusStop', 'NEXT_STOP')
# YIELD nodeId, centrality
# RETURN algo.asNode(nodeId).name AS bus_stop,centrality
# ORDER BY centrality DESC LIMIT 15
# Out:
# 15 rows affected.
# [['Rua Felicio Laskoski, 211 - Riviera', 0.4],
#  ['Rua Felicio Laskoski, 6046 - Riviera', 0.38095238095238093],
#  ['Rua Felicio Laskoski, 6047 - Riviera', 0.38095238095238093],
#  ['Rua Anselmo de Lima Filho, 16 - Cidade Industrial', 0.3333333333333333],
#  ['Rua Anselmo de Lima Filho, 17 - Cidade Industrial', 0.3333333333333333],
#  ['Rua Anselmo de Lima Filho, 216 - Cidade Industrial', 0.27586206896551724],
#  ['Rua Anselmo de Lima Filho, 215 - Cidade Industrial', 0.27586206896551724],
#  ['Rua Padre Jo?o Wislinski, 621 - Santa Candida', 0.22535211267605634],
#  ['Rua Silvano Alves da Rocha Loures, 374 - Riviera', 0.2222222222222222],
#  ['Rua Silvano Alves da Rocha Loures, 375 - Riviera', 0.2222222222222222],
#  ['Terminal Santa Candida - 231 - Banestado / California',
#   0.21333333333333335],
#  ['Terminal Santa Candida - 233 - Olaria', 0.20869565217391303],
#  ['Estrada Santa Candida, 1357 - Tingui', 0.19753086419753085],
#  ['Rodovia Mauro Bernardo Camargo, 154 - Santa Candida', 0.19753086419753085],
#  ['Rua Padre Jo?o Wislinski, 1048  - Santa Candida', 0.19753086419753085]]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match(s:Stop)-[r:EVENT_STOP]->(bs:BusStop)
# return bs.name,s.vehicle,s.line_code,r.line_way,count(s) as stops
# order by stops desc limit 10
# Out:
# 10 rows affected.
# [['Rua Amador Bueno, 1238 - Cajuru',
#   'DA023',
#   '334',
#   'Agricola (Circular)',
#   319],
#  ['Rua Reinaldo Rodrigues Lima, 615 - Cajuru',
#   'DA011',
#   '323',
#   'Circular',
#   291],
#  ['Rua dos Ferroviarios, 1398 - Cajuru', 'DA011', '323', 'Circular', 243],
#  ['Rua Reinaldo Rodrigues Lima, 775 - Cajuru',
#   'DA011',
#   '323',
#   'Circular',
#   211],
#  ['Rua dos Ferroviarios, 1204 - Cajuru', 'DA011', '323', 'Circular', 204],
#  ['Rua Leonardo Novicki, 34 - Cajuru', 'DA011', '323', 'Circular', 192],
#  ['Av. Manoel Ribas, 8320 - Butiatuvinha', 'MN405', '912', 'Jose Culpi', 170],
#  ['Av. Manoel Ribas, 8177 - Butiatuvinha',
#   'MN405',
#   '912',
#   'Terminal Sta. Felicidade',
#   169],
#  ['Rua Benedito Mario da Silva, 153 - Cajuru',
#   'DA015',
#   '332',
#   'Acropole (Circular)',
#   153],
#  ['Terminal Santa Felicidade - 917 - Jardim Ipe',
#   'MA011',
#   '917',
#   'Terminal Sta. Felicidade',
#   152]]

# %%
results = %cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data match(l:Line {line_code:'334'})-[:HAS_TRIP]-(t:Trip)-[:HAS_SCHEDULE_AT]->(sc:Schedule {vehicle:'DA023'}) \
with distinct l.name as line_name, t.line_way as line_way, sc.vehicle as vehicle  \
match (t:Trip {line_way: line_way})-[:STARTS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(ss:Stop {vehicle: vehicle}) \
with ss, line_name , line_way , vehicle \
MATCH(t:Trip {line_way: line_way})-[:ENDS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(se:Stop {vehicle: vehicle}) \
with line_name ,vehicle, line_way,ss.event_time as start_event, se.event_time as end_event where ss.event_time < se.event_time \
with line_name ,vehicle, line_way, start_event, min(end_event) as end_event \
with line_name ,vehicle, line_way, min(start_event) as start_event , end_event \
match (t:Trip {line_way: line_way})-[:STARTS_ON_POINT]->(bs:BusStop )<-[:EVENT_STOP]-(ss:Stop {vehicle: vehicle}) \
where ss.event_time = start_event \
with line_name ,vehicle, line_way, ss,start_event, end_event \
MATCH(t:Trip {line_way: line_way})-[:ENDS_ON_POINT]->(bs:BusStop  )<-[:EVENT_STOP]-(se:Stop {vehicle: vehicle}) \
where se.event_time = end_event \
WITH line_name ,vehicle, line_way, ss, se ,start_event , end_event \
match p = (ss)-[m:MOVED_TO*]->(se) \
with line_name ,vehicle, line_way, start_event , end_event, extract(s in relationships(p) | toFloat(s.delta_time))     as delta_time \
    ,extract(s in relationships(p) | toFloat(s.delta_distance)) as delta_distance \
    ,extract(s in relationships(p) | toFloat(s.delta_velocity)) as delta_velocity \
    ,length(extract(s in nodes(p) where 'Stop' IN LABELS(s) )) as stop \
return line_name ,vehicle, line_way, min(start_event) as start_event, end_event, apoc.coll.sum(delta_time)/60        as time_in_minutes \
      ,apoc.coll.sum(delta_distance)/1000  as distance_in_kilometers \
      ,apoc.coll.avg(delta_velocity)       as velocity_in_kmh \
      ,stop \
order by vehicle,start_event, end_event
# Out:
# 137 rows affected.

# %%
df = results.get_dataframe()
df[(df.distance_in_kilometers > 1)].head()
# Out:
#    line_name vehicle             line_way start_event end_event  \
# 3   AGRICOLA   DA023  Agricola (Circular)    06:24:04  06:49:33
# 5   AGRICOLA   DA023  Agricola (Circular)    06:51:13  07:12:39
# 8   AGRICOLA   DA023  Agricola (Circular)    07:18:24  07:38:44
# 11  AGRICOLA   DA023  Agricola (Circular)    07:45:03  08:06:47
# 14  AGRICOLA   DA023  Agricola (Circular)    08:12:44  08:31:37
#
#     time_in_minutes  distance_in_kilometers  velocity_in_kmh  stop
# 3         25.483333                6.777862        14.299091    34
# 5         21.433333                6.653717        14.491613    32
# 8         20.333333                6.625905        15.069032    32
# 11        21.733333                6.731771        12.913721    44
# 14        18.883333                6.423001        14.461786    29

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match(l:Line {line_code:'334'})-[:HAS_TRIP]-(t:Trip)-[:HAS_SCHEDULE_AT]->(sc:Schedule {vehicle:'DA023'})
# return t.line_way,sc.vehicle,sc.start_time,sc.end_time order by sc.start_time limit 10
# Out:
# 10 rows affected.
# [['Agricola (Circular)', 'DA023', '00:15', '00:35'],
#  ['Agricola (Circular)', 'DA023', '00:35', '05:56'],
#  ['Agricola (Circular)', 'DA023', '05:56', '06:23'],
#  ['Agricola (Circular)', 'DA023', '06:23', '06:50'],
#  ['Agricola (Circular)', 'DA023', '06:50', '07:17'],
#  ['Agricola (Circular)', 'DA023', '07:17', '07:44'],
#  ['Agricola (Circular)', 'DA023', '07:44', '08:11'],
#  ['Agricola (Circular)', 'DA023', '08:11', '08:38'],
#  ['Agricola (Circular)', 'DA023', '08:38', '09:05'],
#  ['Agricola (Circular)', 'DA023', '09:05', '09:32']]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match(bs:BusStop)-[r:NEXT_STOP {line_name:'AGRICOLA'}]->(be:BusStop) return round(100 * sum(r.distance)/1000)/100 as distance
# Out:
# 1 rows affected.
# [[5.08]]

# %%
# %%cypher http://neo4j:neo4j2018@172.17.0.4:7474/db/data
# match(bs:BusStop)-[r:NEXT_STOP {line_name:'AGRICOLA'}]->(be:BusStop) return count(bs)
# Out:
# 1 rows affected.
# [[23]]
